# %%
"""
Created by Tommaso Mazzucco

10/20/2020

"""
"""
Docstring:

Inspired by 2000 Disney Movie "Emperor's New Groove",
This game is set in the ancient Inca Empire and the user is going to impersonate
The Emperor who is tranformed into a llama by his personal assistant.
He is being sent to a village.
The game consists of 4 stages:
1st stage) multiple choice to get across the jungle
2nd stage) multiple choice to get across a bridge
3rd stage) answer to a set of randomly chosen Q. by the guard of the castle
4th stage) Answer to a joke to unlock the lab and come back as a human

Known Bugs: None

"""





#Before starting the game imported exit and import funsction 

from sys import exit
import random

def game_start(): #defining name of the user and use it for the whole game
    global user_name
   

    
user_name = input (prompt ='Enter Username \t')
print(f"Welcome {user_name} to the Inca Empire!")

# Introducing the user to the game setting

print("""
In this Game you are going to be nothing less than the Emperor!
That's lucky! mmh.... well let's see how you manage your leadership
""")
print(70*'*')
input('<Press Enter>')
print("""
While you approach your lavish banquet for breakfast,
you salute your personal assistant, Yzma, who seems weirdly overwelmed.
As you drink your daily orange juice something weird happens...
your hands have turned into clogs!
Wha...what??What have I smoked yesterday night?
Involved in these thoughts you don't notice a jute sack coming from above
and wrapping up your body!
""")
print(70*'*')
input('<Press Enter>')
print("""
You wake up in a village the next day but nodoby seems to recognize you...
You come to a puddle and you can't believe what you are seeing...
""")
input('<Press Enter>')
print(""" You've turned into a llama!!!
A farmer from the village notices you and he can't believe that: 
There's a llama talking!
His name is Pacha and ,nonetheless, he believes you
and offers to help you come back to your castle.
""")
print('*'* 70)

#Game begins with defining the crossing jungle stage 

def crossing_jungle():
    print("""
    There's a deep tropical forest towards your Fort,
    What would you do now?
    1) Cross the jungle along with Pacha
    2) Take your own path alone
    3) Remain in the village and live as a Llama""")
    
    choice = input("  \n")  

#Nesting conditions for the multiple choice    
    
    if choice == '1':
        print("\nPacha's expertise is helpful and you cross safely")    
        input("<Press enter to continue>")
        wooden_bridge()
        
    
    elif choice == '2':
        print("""\n Not a wise choice, Jaguars happen to be very hungry. 
    Game Over.""")
        
        fail() #fail function has been defined on bottom of the code
    
    elif choice == '3':
        print("""
        You were an Emperor just 1 day ago!
        Come on, come back were you belong!
        """ )
        input("<Press enter to continue>\n")
        crossing_jungle()        #the player goes back to the question, for an invalid entry
    else:
        print("Invalid command. Please try again.")
        input("<Press enter to continue>\n")
        crossing_jungle()    

crossing_jungle()

print('*'*70)
#Next stage is basically the same process as before with multiple choice questions       
def wooden_bridge():
    print("""
    An old wooden bridge comes along your way.
    It seems quite shaky but it is the only way to avoid the jungle.
    Pacha,as altruistic as he is, proceeds foward first.
    Halfways his foot get stuck and now his head is facing downwards the precipice
    What are your actions?
    
    1)Help Pacha,look what he has been doing for you
    2)Walk on him,proceed your way to the castle
    3)Mumble mumble
    """)
    
    choice = input("  \n")
    
    if choice == '1':
        print("""
        Great choice, your loyal compadre is now back on track,
        off to the castle!
        """)
        input("<Press enter to continue>")
        the_castle() #nested condition the player goes to the next round by pressing enter
    
    elif choice == '2':
        print("""
        You continue by yourself,but you get lost
        """)
        fail() #fail function has been defined at the bottom of the code
    
    elif choice == '3':
        print("Take a choice!")
        input("<Press enter to continue>\n")
        wooden_bridge()        
    
    else:
        print("Invalid command. Please try again.")
        input("<Press enter to continue>\n")
        wooden_bridge()


        
print('*'* 70)
#in this round we are going to have a while loop containing a list of questions chose randomly
def the_castle():
    print("""
    Pacha already knows the shortcut and in good amount of time
    you've reached the castle!
    Now all you have to do is prove that you are the Emperor
    and Yzma betrayed you.
    You try to convince the guard at the entrance but
    he doesn't recognize you...well, you are a llama!
    Hence he asks you some questions to verify your identity
    """)


# Created a list of questions to be asked randomly
    
    guard_list = ['What is your favourite song?',
                  'What is your favourite pasta sauce?',
                  'What kind of pet does the Emperor have?',
                  'What is your favourite sport?']
    questions = 2     #only 2 Qs will be asked
    list_new = list()    #creating an empty list to store the already asked questions
    while questions > 0:
        question = random.choice(guard_list)
        while (question in list_new):
            question = random.choice(guard_list)
        list_new.append(question)                  #this appends the asked question to the empty list so that is not going to be asked anymore in the game
        input("<Press enter for your question>\n")
        print(question)
        print(" ") #this begins the process of showing the questions to the user
        
        if question == guard_list[0]:
            song = input("Your favourite song: \n")
            print(f"Guard:{song} is the Emperor's favourite song!")
            questions -=1 
        
        elif question == guard_list[1]:
            print(" 1) Carbonara")
            print(" 2) Eggnog")
            print(" 3) The Emperor doesn't like pasta")
            
            pasta = input("> \n")
            
            if pasta == '1':
                print("That's correct! Original Recipe with Guanciale.\n")
                questions -=1  #by getting the right answer -=1 lets you have only another Qs to guess right
            
            else:
                print("You are mistaken. The real Emperor likes OG italian pasta")
                fail()

        elif question == guard_list[2]:
            print(" 1) A Rynoceros")
            print(" 2) A dog")
            print(" 3) A Platypus")
            
            animal = input ("> \n")
            
            if animal == '3':
                print (" Wonderful! correct the Emperor is obsessed about Platypuses")
                questions -=1
            else:
                print(" You are mistaken, The Emperor likes a really rare and little animal as a pet")
                fail()
        
        elif question == guard_list[3]:  #printing multiple choice question inside the while loop
            print(" 1) Tennis")
            print(" 2) Athletics")
            print(" 3) Birdwatching")
        
            sport = input("> \n")
        
            if sport == '3':
                print("Trick Question...Correct! The Emperor is very lazy")
                questions -=1
            else:
                print(" Incorrect answer, The Emperor is actually very lazy")
                fail()
               
    print("You made it inside the castle!\n")
    input("<Press enter to continue>\n")
    lab()
#the end of the game the user has to answer between two choices
def lab():
    print(f"""
    You've sneaked now in the lab!
    Congrats {user_name}!!
    Nonetheless, the door is locked...
    To access you have to choose the correct answer to Yzma's
    favourite corny joke:
    what animal's favourite weather is rain?
    1) fish
    2) drizzly bear
    """)
    
    choice = input("  \n")
    
    #nested conditions
    
    if choice == '1':
        print("""Access Denied... such a pity,
    antidote was just inside the lab""")
        fail() #the user has failed and has to replay the game
    
    elif choice == '2':
        print(""" Yes the door opens! 
    You miraculously find the antidote and you are back to human!
    Yzma's plan to detronize you failed!
    You can now prove the Emperor is still alive and you are back
    on the Throne!
    """)#winning the game with exit function
        exit()
    
    else:
        print("Invalid command. Please try again.")
        input("<Press enter to continue>\n")
        lab() #sending back to the last question
    


#function makes the user choose between re begin the game at the crossing jungle or .. exit it

def fail():
    print(f"You've failed {user_name}, but thanks for playing!""")
    input("<Press Enter to Continue>")
    restart_game = input("""Would you like to replay the Game? (Yes/No) """)
    restart_game = restart_game.lower()
    print(restart_game)
    
    if 'yes' in restart_game or 'y' in restart_game:
        crossing_jungle()  #back to first stage
        
    else:
        print(f"""
        All right {user_name}! Thank you for playing
        See ya!""")
        input(""" <Press Enter to exit>""")
        exit(0)
    
fail()
# Out:
# Enter Username 	txfcy
# Welcome txfcy to the Inca Empire!
#
# In this Game you are going to be nothing less than the Emperor!
# That's lucky! mmh.... well let's see how you manage your leadership
#
# **********************************************************************
# <Press Enter>
#
# While you approach your lavish banquet for breakfast,
# you salute your personal assistant, Yzma, who seems weirdly overwelmed.
# As you drink your daily orange juice something weird happens...
# your hands have turned into clogs!
# Wha...what??What have I smoked yesterday night?
# Involved in these thoughts you don't notice a jute sack coming from above
# and wrapping up your body!
#
# **********************************************************************
# <Press Enter>
#
# You wake up in a village the next day but nodoby seems to recognize you...
# You come to a puddle and you can't believe what you are seeing...
#
# <Press Enter>
#  You've turned into a llama!!!
# ...
